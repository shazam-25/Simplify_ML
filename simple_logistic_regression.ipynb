# %% [markdown]
# <a href="https://colab.research.google.com/github/shazam-25/Simplify_ML/blob/main/simple_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
# Sample Dataset
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([0, 0, 0, 1, 1])

# %%
# Model
model = LogisticRegression()
# Model Training
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
# Predictions for plotting
X_plot = np.linspace(0, 6, 100).reshape(-1, 1)
y_plot = model.predict_proba(X_plot)[:, 1]

# %%
# Plot
plt.figure(figsize=(8,6))
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X_plot, y_plot, color='red', label='Predicted Probability', )
plt.xlabel('X (independent)')
plt.ylabel('y (dependent)')
plt.legend()
plt.title('Logistic Regression')
plt.show()
