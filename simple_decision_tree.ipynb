# %% [markdown]
# <a href="https://colab.research.google.com/github/shazam-25/Simplify_ML/blob/main/simple_decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
# Load dataset
iris = load_iris()
X, y = iris.data, iris.target
print(f'Feature set shape: {X.shape}')
print(f'Target set shape: {y.shape}')
# Out:
# Feature set shape: (150, 4)
# Target set shape: (150,)

# %%
# Model
model = DecisionTreeClassifier(max_depth=3, random_state=42)
# Model Training
model.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
# Visulaize Tree
plt.figure(figsize=(10, 10))
plot_tree(model, feature_names=iris.feature_names,
         class_names=iris.target_names, filled=True)
plt.show()
