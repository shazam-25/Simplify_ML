# %% [markdown]
# <a href="https://colab.research.google.com/github/shazam-25/Simplify_ML/blob/main/hierarchical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# Sample data
X, _ = make_blobs(n_samples=30, centers=3, random_state=42, cluster_std=1.0)

# %%
# Agglomerative clustering (bottom-up)
linkage_matrix = linkage(X, method='ward')
plt.figure(figsize=(10,4))
plt.title('Agglomerative Hierarchical Clustering Dendrogram')
dendrogram(linkage_matrix)
plt.show()

# %%
# Divisive clustering (top-down)
# Using fcluster to split into 3 clusters
from scipy.cluster.hierarchy import inconsistent
clusters = fcluster(linkage_matrix, t=3, criterion='maxclust')
plt.scatter(X[:,0], X[:,1], c=clusters, cmap='viridis', s=50)
plt.title('Divisive Clustering (approximation)')
plt.show()
